# %% [markdown]
# # Moon

# %%
import pandas as pd
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import itertools

# %%
sample = 600
#seed = 3655
#seed = 3656
seed = 3657

X, y = make_moons(n_samples = sample, noise=0.05, random_state = seed)


plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis')
plt.show()

# %%
df = pd.DataFrame(data=X, columns=['Feature_1', 'Feature_2']).round(3)
df['target'] = y

# %%
df.head()
# Out:
#    Feature_1  Feature_2  target
# 0     -0.768      0.677       0
# 1      1.847      0.148       1
# 2     -1.072      0.412       0
# 3      1.967      0.039       1
# 4     -0.044      0.932       0

# %%
num_train = 300
sample_num = int(num_train/2)

df_1 = df[df['target'] == 1].sample(n=sample_num, random_state=seed)
df_0 = df[df['target'] == 0].sample(n=sample_num, random_state=seed)


df_train = pd.DataFrame()
df_len = len(df_1)
for i in range(df_len):
    df1 = pd.DataFrame([df_1.iloc[i]])
    df0 = pd.DataFrame([df_0.iloc[i]])
    df_train = pd.concat([df_train, df1, df0])

df_train['target'] = df_train['target'].astype(int)
df_test = df.drop(df_train.index)

df_test = df.drop(df_train.index)

path = '../../data/moon/'
df_train.to_csv(path + f'moon_{seed}_{num_train}_train.csv', index=False)
df_test.to_csv(path + f'moon_{seed}_{num_train}_test.csv', index=False)

# %%
df_train.head()
# Out:
#      Feature_1  Feature_2  target
# 35       1.131     -0.562       1
# 22       0.926      0.096       0
# 453      1.314     -0.443       1
# 464      0.990      0.242       0
# 221      2.050      0.283       1
